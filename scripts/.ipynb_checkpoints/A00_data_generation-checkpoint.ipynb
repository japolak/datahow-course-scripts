# %% [markdown]
# # Data generation

# %% [markdown]
# ## Initial setup

# %% [markdown]
# Here, the necessary libraries are being setup

# %%
import pandas as pd
import numpy as np
import scipy
import pyDOE2
import importlib  
import scipy.integrate

# import custom modules
from modules import emulator
from modules.transformations import owu_from_csv

#notebook settings
pd.set_option('display.max_rows', 30)

# %% [markdown]
# The emulator is aimed at providing in-silico data to test some of the machine learning tool discussed during the course.
# The emulator is mimicking the behavior of a fed-batch cell culture process, where only few components are present:
# - The cells, responsible for the production of the product, which are consuming glucose to sustain metabolism and producing lactate as by-product. These are indicated by VCD (viable cell density), typically expressed in million cells / ml.
# - Glucose (Glc) is consumed by the cells and it is continuously fed to the process (F_glc). Too low glucose concentrations are slowing down cell growth and product production. To high glucose concentrations are poisoning the system and accelerating cell death.
# - Lactate (Lac) is a by-product of the cells and it is poisoning the cells, so that too high lactate concentrations are slowing down cell metabolism and accelerating cell death
# - Product (Prod) is produced by the cells. The faster the cells are growing, the less are producing the product.

# %% [markdown]
# ## Model Equations

# %% [markdown]
# The emulator's results are based on the following equations to create the in-sillico data

# %% [markdown]
# - Balance on VCD:  $\frac{dVCD}{dt}$ = (μ<sub>g</sub> - μ<sub>d</sub>)VCD
# - Balance on Glucose: $\frac{dGlc}{dt}$ = $-k_{Glc} \frac{Glc}{Glc + 0.05}$ VCD + F<sub>Glc</sub>
# - Balance on Lactate: $\frac{dLac}{dt}$ = k<sub>Lac</sub> VCD
# - Balance on Product: $\frac{dProd}{dt}$ = k<sub>Prod</sub>$\frac{Glc}{Glc + K_{g, Glc} }$ ($\frac{μ_{g}}{μ_{g,max}}$)<sup>2</sup>VCD
#
# Where:
# - Growth rate: $μ_{g} =  μ_{g,max}\frac{Glc}{Glc +K_{g, Glc}}\frac{K_{i, Lac}}{Lac+K_{i, Lac}} $
# - Death rate: $μ_{d} = μ_{d,max}(1+\frac{φ}{1+φ})\frac{Lac}{Lac+K_{d, Lac}}$
# - Glc saturation: φ = e<sup>0.1(Glc-75)</sup>
#
# $\frac{}{}$

# %% [markdown]
# ## Parameter selection

# %% [markdown]
# The emulator will simulate a predefined number of experiments. The results of those experiments is based on the   intervals of the desired parameters (from initial conditions to the number of experiments). These experiments will then be used to create the dataset that will be used in the subsequent sections of the code. You will have the opportunity to define those ranges in the sections below.

# %% [markdown]
# ### Model parameters' values

# %% [markdown]
# Define the value range of the maximum growth rate interval $μ_{g,max}$

# %%
mu_g_max = 0.01

# %% [markdown]
# Define the value range of the maximum death rate interval $μ_{d,max}$

# %%
mu_d_max = 0.025

# %% [markdown]
# Define the value range of the $K_{g,Glc}$

# %%
K_g_Glc = 1

# %% [markdown]
# Define the value range of the $K_{g,Lac}$

# %%
K_g_Lac = 50

# %% [markdown]
# ### Process parameters' ranges

# %% [markdown]
# Define the value range of the $K_{I,Lac}$

# %%
K_I_Lac = [30, 50]

# %% [markdown]
# Define the value range of the $K_{d,Lac}$

# %%
K_d_Lac = 50

# %% [markdown]
# Define the value range of the $k_{Glc}$

# %%
k_Glc = 0.04

# %% [markdown]
# Define the value range of the $k_{Lac}$

# %%
k_Lac = 0.06

# %% [markdown]
# Define the value range of the $k_{prod}$

# %%
k_Prod = 1

# %% [markdown]
# Define the value range of the days at which Glc feed is started

# %%
feed_start = [3, 6]

# %% [markdown]
# Define the value range of the days at which Glc feed is ended

# %%
feed_end = [12.0, 16]

# %% [markdown]
# Define the Glc feed rate

# %%
Glc_feed_rate = [12.0, 15.0]

# %% [markdown]
# Define the initial glucose feed values ranges

# %%
Glc_0 = [12.0, 15.0]

# %% [markdown]
# Define the initial VCD value ranges

# %%
VCD_0 = [0.3, 0.6]

# %% [markdown]
# Define the number of experiments to be generated in the simulator

# %%
num_exp = 20

# %% [markdown]
# Here, an aggregation of the generated data is shown in table form

# %%
var_lims = {"mu_g_max":mu_g_max,
    "mu_d_max": mu_d_max,
    "K_g_Glc" : K_g_Glc,
    "K_g_Lac" : K_g_Lac,
    "K_I_Lac" : K_I_Lac,
    "K_d_Lac" : K_d_Lac,
    "k_Glc" : k_Glc,
    "k_Lac" : k_Lac,
    "k_Prod" : k_Prod,
    "feed_start" : feed_start,
    "feed_end" : feed_end,
    "Glc_feed_rate" : Glc_feed_rate,
    "Glc_0" : Glc_0,
    "VCD_0" : VCD_0}


# Use the function to generate data
filename = "mytable.csv"
data = emulator.generate_data(var_lims, num_exp, filename)
data
# Out:
#      timestamps      X:VCD         X:Glc      X:Lac   X:Titer
# 0           0.0  13.500000  1.350000e+01   0.000000  0.000000
# 1           1.0  12.471011  1.939507e-07  12.610067  0.000551
# 2           2.0  10.345833  1.390843e-03  23.602078  0.021154
# 3           3.0   8.077586  1.795428e-03  32.434068  0.041876
# 4           4.0   6.081902  2.413024e-03  39.201259  0.062781
# ..          ...        ...           ...        ...       ...
# 295        10.0   0.894526  4.371685e-09  51.582838  0.113142
# 296        11.0   0.642042 -3.163714e-08  52.313848  0.113142
# 297        12.0   0.460012 -4.976375e-09  52.838048  0.113142
# 298        13.0   0.329179  6.798809e-09  53.213393  0.113142
# 299        14.0   0.235348 -8.165850e-09  53.481863  0.113142
#
# [300 rows x 5 columns]

# %% [markdown]
# ## Generate a single experiment

# %% [markdown]
# Alternatively, you can run the simulator to obtain one singular experiment by defining the variable values

# %%
# Model parameters
mu_g_max = 0.05;
mu_d_max = 0.025;
K_g_Glc  = 1;
K_I_Lac  = 30;
K_d_Lac  = 50;
k_Glc    = 0.04;
k_Lac    = 0.06;
k_Prod   = 1;
model_param = [mu_g_max,mu_d_max,K_g_Glc,K_I_Lac,K_d_Lac,k_Glc,k_Lac,k_Prod]

# Process parameters
feed_start = 3.0
feed_end = 12.0
Glc_feed_rate = 0.50
Glc_0 = 12.0
VCD_0 = 0.5
process_param = [feed_start,feed_end,Glc_feed_rate,Glc_0,VCD_0]

# Experiment run generation
t,y = emulator.predict_chrom_phase(model_param,process_param)
run_df = pd.DataFrame(y,columns=["X:VCD", "X:Glc", "X:Lac", "X:Titer"])
run_df
# Out:
#         X:VCD      X:Glc       X:Lac      X:Titer
# 0    0.500000  12.000000    0.000000     0.000000
# 1    1.471551  11.134896    1.303268     0.199102
# 2    3.869848   8.732356    4.925306     1.952155
# 3    7.907237   3.195349   13.306272    16.391986
# 4   12.101564   5.673504   27.739503    67.774204
# 5   14.782388   4.689308   47.397539   175.129793
# 6   14.749745   2.504735   68.981167   325.323861
# 7   12.664054   1.598027   88.865400   469.944302
# 8   10.290136   2.880981  105.346429   599.963298
# 9    8.330067   6.080447  118.708868   723.413889
# 10   6.681738  10.940860  129.484706   832.655877
# 11   5.292161  17.234186  138.076141   924.413087
# 12   4.140986  24.735436  144.840690   999.037062
# 13   3.204551  21.233657  150.105089  1058.079304
# 14   2.457605  18.536700  154.160712  1103.830453

# %% [markdown]
# ## Construction of an OWU matrix from the generated data

# %% [markdown]
# For better visualisation of the in-sillico data, the data was reshaped into an OWU matrix. So, the values of each variable are separated by experiment.

# %%
import importlib  
import pandas as pd
filename = "mytable.csv"
owu = owu_from_csv(filename)

pd.set_option('display.max_rows', None)

owu
# Out:
#                     X:VCD         X:Glc      X:Lac   X:Titer
# run timestamps
#  0  0.0         13.500000  1.350000e+01   0.000000  0.000000
#     1.0         12.471011  1.939507e-07  12.610067  0.000551
#     2.0         10.345833  1.390843e-03  23.602078  0.021154
#     3.0          8.077586  1.795428e-03  32.434068  0.041876
#     4.0          6.081902  2.413024e-03  39.201259  0.062781
#     5.0          4.475597  1.538720e-10  44.237317  0.073330
#     6.0          3.244658 -1.276001e-09  47.915062  0.073330
#     7.0          2.329278 -1.442954e-09  50.568092  0.073330
#     8.0          1.661087 -1.112749e-07  52.466290  0.073330
#     9.0          1.179218 -7.306306e-08  53.816875  0.073330
#     10.0         0.834521 -1.126529e-08  54.774181  0.073330
#     11.0         0.589301  1.810065e-08  55.450938  0.073330
#     12.0         0.415512 -5.171799e-08  55.928460  0.073330
#     13.0         0.292670  5.450554e-09  56.264963  0.073330
#     14.0         0.205994  1.354130e-08  56.501896  0.073330
#  1  0.0         13.026316  1.286842e+01   0.000000  0.000000
#     1.0         11.894870  8.260318e-06  12.116621  0.000547
#     2.0          9.663138  1.631048e-03  22.498019  0.023086
#     3.0          7.378965  2.157727e-03  30.659912  0.045790
#     4.0          5.437463 -5.743270e-11  36.778505  0.062075
#     5.0          3.919869 -2.291775e-09  41.236660  0.062075
#     6.0          2.787221 -3.610813e-09  44.428138  0.062075
#     7.0          1.964154 -7.477957e-08  46.687163  0.062075
#     8.0          1.375919  3.083422e-10  48.274323  0.062075
#     9.0          0.959995 -1.265133e-09  49.383948  0.062075
#     10.0         0.667980 -5.396159e-09  50.157091  0.062075
#     11.0         0.463930  2.465609e-08  50.694549  0.062075
#     12.0         0.321804 -4.404155e-08  51.067581  0.062075
#     13.0         0.223025  4.166118e-09  51.326217  0.062075
#     14.0         0.154473  3.753038e-11  51.505411  0.062075
#  2  0.0         13.815789  1.302632e+01   0.000000  0.000000
#     1.0         12.672023  4.218850e-06  12.871708  0.000548
#     2.0         10.376050  1.322468e-03  23.972533  0.020199
#     3.0          7.989074  1.731275e-03  32.771362  0.039963
#     4.0          5.934511  2.358919e-03  39.421151  0.059906
#     5.0          4.312240  3.305022e-03  44.305274  0.080116
#     6.0          3.089154 -1.384624e-10  47.828876  0.092533
#     7.0          2.191910 -1.199230e-08  50.340657  0.092533
#     8.0          1.545641 -1.491696e-08  52.117389  0.092533
#     9.0          1.085345 -1.427068e-09  53.367653  0.092533
#     10.0         0.759939  2.822265e-08  54.244344  0.092533
#     11.0         0.531050 -2.132450e-08  54.857567  0.092533
#     6.0          2.912961  1.777286e-10  47.224685  0.103980
#     7.0          2.044184 -1.614268e-08  49.580818  0.103980
#     8.0          1.426200 -2.057459e-08  51.229498  0.103980
#     9.0          0.991169 -2.201887e-08  52.377547  0.103980
#     10.0         0.687023 -3.358793e-08  53.174341  0.103980
#     11.0         0.475354  3.715935e-08  53.726141  0.103980
#     12.0         0.328501  1.429766e-08  54.107683  0.103980
#     13.0         0.226826 -2.728000e-08  54.371245  0.103980
#     14.0         0.156531 -5.998020e-10  54.553178  0.103980
#     0.0         14.131579  1.413158e+01   0.000000  0.000000
# -1  1.0         12.991431  6.395823e-06  13.176985  0.000554
#     2.0         10.681466  1.262958e-03  24.579613  0.019879
#     3.0          8.260118  1.645359e-03  33.656413  0.039308
#     4.0          6.160460 -2.471768e-10  40.545121  0.043932
#     5.0          4.492806 -2.474494e-09  45.624080  0.043932
#     6.0          3.229923 -5.816338e-09  49.301226  0.043932
#     7.0          2.300175 -2.373334e-08  51.932150  0.043932
#     8.0          1.627708 -7.568918e-09  53.799775  0.043932
#     9.0          1.146896 -4.843435e-08  55.118535  0.043932
#     10.0         0.805728  9.142072e-08  56.046422  0.043932
#     11.0         0.564905  9.302404e-09  56.697595  0.043932
#     12.0         0.395505  1.775741e-09  57.153823  0.043932
#     13.0         0.276638 -3.046385e-09  57.473075  0.043932
#     14.0         0.193364  9.469437e-12  57.696304  0.043932
#  19 0.0         12.078947  1.255263e+01   0.000000  0.000000
#     1.0         11.271088  4.144455e-06  11.323460  0.000545
#     2.0          9.532801  1.701269e-03  21.348015  0.023742
#     3.0          7.602216  2.151899e-03  29.568971  0.047086
#     4.0          5.844831  2.835592e-03  36.002122  0.070659
#     5.0          4.389069  3.848511e-03  40.888787  0.094570
#     6.0          3.244520 -1.183550e-10  44.529332  0.113142
#     7.0          2.372061  1.948789e-09  47.205336  0.113142
#     8.0          1.721602 -3.420475e-08  49.154511  0.113142
#     9.0          1.243185 -4.203944e-08  50.565631  0.113142
#     10.0         0.894526  4.371685e-09  51.582838  0.113142
#     11.0         0.642042 -3.163714e-08  52.313848  0.113142
#     12.0         0.460012 -4.976375e-09  52.838048  0.113142
#     13.0         0.329179  6.798809e-09  53.213393  0.113142
#     14.0         0.235348 -8.165850e-09  53.481863  0.113142

# %% [markdown]
# Furthermore, the evolution of each variable with respect to time is also visible here, but this time in the form of a graph

# %%
from matplotlib import pyplot as plt

#[print(run) for ix,run in owu.groupby("run")]
columns = list(owu.columns)
num_vars=len(columns)


for run_ix,run in owu.groupby("run"):
    fig, axs = plt.subplots(1,num_vars)
    fig.suptitle(f'X variable evolution on run {run_ix}')
    for plot_ix, col in enumerate(columns):
        axs[ plot_ix].plot(run.index.get_level_values("timestamps"),list(run[col].values))
        axs[ plot_ix].set_title(f'{col}')
        plt.subplots_adjust(right=3)

# %% [markdown]
# Now, to visualise the daa in another way, the data of all runs will be shown in a single graph

# %%
fig, axs = plt.subplots(num_vars,figsize=(15,30))
units_list =[""]
for run_ix,run in owu.groupby("run"):
    fig.suptitle(f'X variable evolution on run {run_ix}')
    for plot_ix, col in enumerate(columns):
        axs[ plot_ix].plot(run.index.get_level_values("timestamps"),list(run[col].values),label=f'run {run_ix}')
        axs[ plot_ix].set_title(f'{col}')
        #plt.subplots_adjust(right=3)
        axs[ plot_ix].set_xlabel("Time (days)")
        axs[ plot_ix].set_ylabel("Amount")
        axs[plot_ix].legend(loc="best")

# %%
fig, axs = plt.subplots(num_vars,figsize=(15,30))
units_list =[""]
for run_ix,run in owu.groupby("run"):
    fig.suptitle(f'X variable evolution on run {run_ix}')
    for plot_ix, col in enumerate(columns):
        axs[ plot_ix].plot(run.index.get_level_values("timestamps"),list(run[col].values),label=f'Final titer: {round(run["X:Titer"].iloc[-1],5)}')
        axs[ plot_ix].set_title(f'{col}')
        #plt.subplots_adjust(right=3)
        axs[ plot_ix].set_xlabel("Time (days)")
        axs[ plot_ix].set_ylabel("Amount")
        axs[plot_ix].legend(loc="best")

# %% [markdown]
# ## PCA Analysis of the OWU Matrix

# %% [markdown]
# Beyond just visualisation, the OWU matrix can also be utilised to plot the degree of correlation between the different variables. For instance, below, the correlation matrix of our variables will be shown

# %%
owu.corr()
# Out:
#             X:VCD     X:Glc     X:Lac   X:Titer
# X:VCD    1.000000  0.542475 -0.963632 -0.814255
# X:Glc    0.542475  1.000000 -0.653373 -0.486098
# X:Lac   -0.963632 -0.653373  1.000000  0.799495
# X:Titer -0.814255 -0.486098  0.799495  1.000000

# %% [markdown]
# ### PCA on "unnormalised" data

# %% [markdown]
# Here, PCA will be applied to the data before any normalisation is applied

# %%
from sklearn.decomposition import PCA
import numpy as np

pca = PCA(n_components = 4)
pca.fit(owu)
expl_var = pca.explained_variance_
expl_var_ratio_ = pca.explained_variance_ratio_
expl_var
# Out:
# array([3.22800841e+02, 6.84396142e+00, 1.04241015e+00, 3.29252079e-04])

# %%
import numpy as np

cum_sum_exp = np.cumsum(expl_var_ratio_)
plt.bar(range(0,len(expl_var_ratio_)), expl_var_ratio_, alpha=0.5, align='center', label='Individual explained variance')
#plt.step(range(0,len(expl_var_ratio_)), expl_var_ratio_, where='mid',label='Cumulative explained variance')
plt.plot(range(0,len(expl_var_ratio_)), 1-expl_var_ratio_,"ro-",label='Cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.tight_layout()
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Normalised PCA

# %% [markdown]
# Now, PCA will be ran on normalised data

# %%
from sklearn.preprocessing import StandardScaler

data_scaler = StandardScaler()

scaled_data = data_scaler.fit_transform(owu)
scaled_data
# Out:
# array([[ 2.03340593,  3.73386651, -2.44950584, -1.82246918],
#        [ 1.80419314, -0.26683184, -1.71907867, -1.8049113 ],
#        [ 1.33079868, -0.26641973, -1.08237607, -1.14834289],
#        ...,
#        [-0.87131997, -0.2668319 ,  0.61109204,  1.78311842],
#        [-0.9004637 , -0.2668319 ,  0.63283355,  1.78311841],
#        [-0.92136502, -0.2668319 ,  0.64838447,  1.78311841]])

# %%
pca.fit(scaled_data)
expl_var_scaled = pca.explained_variance_
expl_var_ratio_scaled = pca.explained_variance_ratio_
expl_var_scaled

cum_sum_exp = np.cumsum(expl_var_ratio_scaled)
plt.bar(range(0,len(expl_var_ratio_scaled)), expl_var_ratio_scaled, alpha=0.5, align='center', label='Individual explained variance')
plt.plot(range(0,len(expl_var_ratio_scaled)), 1-expl_var_ratio_scaled,"ro-",label='Cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.tight_layout()
plt.legend(loc='best')
plt.show()

# %%
def myplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley,s=5)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
 
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()
pca_data = pca.fit_transform(scaled_data)
myplot(pca_data[:,0:2],np.transpose(pca.components_[0:2, :]),list(owu.columns))
